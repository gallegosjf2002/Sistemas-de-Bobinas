# %%
# Importar librerías
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import dblquad
from mpl_toolkits.mplot3d import Axes3D

# %%
#parametros generales
d = 15* 10**(-2) # Separación de las bobinas (m)
mu_0 = 4 * np.pi * 1e-7

# %% [markdown]
# BOBINA 1

# %%
#Definir Parametros Bobina 1
N_1 = 435 # Número de vueltas
R_min1 = 0 # Radio de las bobinas (m)
R_max1 = 14* 10**(-2)
I1 = 0.025 # Corriente (A)
k1 = mu_0 * N_1 * I1 / (4* np.pi) # Constante

def B_x1(x, y, z, a, b):
  def f(R,phi):
    return (z - R*np.sin(phi) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min1, R_max1, 0, 2* np.pi)
  return k1 * integral
def B_y1(x, y, z, a, b):
  def f(R,phi):
    return (R*np.cos(phi)-z)/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min1, R_max1, 0, 2* np.pi)
  return  k1 * integral
def B_z1(x, y, z, a, b):
  def f(R,phi):
    return ((R)*(np.sin(phi)-np.cos(phi)) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min1, R_max1, 0,  2*np.pi)
  return k1 * integral

# %% [markdown]
# BOBINA 2

# %%
#Definir Parametros Bobina 1
N_2 = 500 # Número de vueltas
R_min2 = 0 # Radio de las bobinas (m)
R_max2 = 14* 10**(-2)
I2 = 0.02 # Corriente (A)
k2 = mu_0 * N_2 * I2 / (4* np.pi) # Constante

def B_x2(x, y, z, a, b):
  def f(R,phi):
    return (z - R*np.sin(phi) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min2, R_max2, 0, 2* np.pi)
  return k2 * integral
def B_y2(x, y, z, a, b):
  def f(R,phi):
    return (R*np.cos(phi)-z)/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min2, R_max2, 0, 2* np.pi)
  return  k2 * integral
def B_z2(x, y, z, a, b):
  def f(R,phi):
    return ((R)*(np.sin(phi)-np.cos(phi)) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min2, R_max2, 0,  2*np.pi)
  return k2 * integral

# %% [markdown]
# BOBINA 3

# %%
#Definir Parametros Bobina 3
N_3 = 110 # Número de vueltas
R_min3 = 0 # Radio de las bobinas (m)
R_max3 = 14* 10**(-2)
I3 = 0.05 # Corriente (A)
k3 = mu_0 * N_3 * I3 / (4* np.pi) # Constante

def B_x3(x, y, z, a, b):
  def f(R,phi):
    return (z - R*np.sin(phi) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min3, R_max3, 0, 2* np.pi)
  return k3 * integral
def B_y3(x, y, z, a, b):
  def f(R,phi):
    return (R*np.cos(phi)-z)/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min3, R_max3, 0, 2* np.pi)
  return  k3 * integral
def B_z3(x, y, z, a, b):
  def f(R,phi):
    return ((R)*(np.sin(phi)-np.cos(phi)) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min3, R_max3, 0,  2*np.pi)
  return k3 * integral

# %% [markdown]
# BOBINA 4

# %%
#Definir Parametros Bobina 4
N_4 = 5000 # Número de vueltas
R_min4 = 0 # Radio de las bobinas (m)
R_max4 = 14* 10**(-2)
I4 = 0.05 # Corriente (A)
k4 = mu_0 * N_4 * I4 / (4* np.pi) # Constante

def B_x4(x, y, z, a, b):
  def f(R,phi):
    return (z - R*np.sin(phi) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min4, R_max4, 0, 2* np.pi)
  return k4 * integral
def B_y4(x, y, z, a, b):
  def f(R,phi):
    return (R*np.cos(phi)-z)/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min4, R_max4, 0, 2* np.pi)
  return  k4 * integral
def B_z4(x, y, z, a, b):
  def f(R,phi):
    return ((R)*(np.sin(phi)-np.cos(phi)) )/ (((x - a)**2 + (y - b)**2 + (z - R * np.sin(phi))**2)**(3/2))
  integral, error = dblquad(f, R_min4, R_max4, 0,  2*np.pi)
  return k4 * integral

# %%
# Definir el rango de valores para x e y
x = np.linspace(-d/4, d/4, 20)
y = np.linspace(-d/4, d/4, 20)

# %%
# Crear una malla de puntos
X, Y = np.meshgrid(x, y)
# Inicializar una matriz vacía para el campo magnético
Bx= np.empty(shape=[X.shape[0], X.shape[1]], dtype=np.float64)
By= np.empty(shape=[X.shape[0], X.shape[1]], dtype=np.float64)
Bz= np.empty(shape=[X.shape[0], X.shape[1]], dtype=np.float64)
B= np.empty(shape=[X.shape[0], X.shape[1]], dtype=np.float64)

# %%
# Calcular el campo magnético en cada punto de la malla de x
for i in range(len(x)):
    for j in range(len(y)):
            # Sumar los campos de las 4 bobinas
           Bx[i, j] = B_x1(x[i], y[j],0, d/2, 0) + B_x2(x[i], y[j],0, -d/2, 0) + B_x3(x[i], y[j], 0, 0, d/2) + B_x4(x[i], y[j], 0, 0, -d/2)

# %%
# Calcular el campo magnético en cada punto de la malla de y
for i in range(len(x)):
    for j in range(len(y)):
            # Sumar los campos de las 4 bobinas
           By[i, j] = B_y1(x[i], y[j],0, d/2, 0) + B_y2(x[i], y[j],0, -d/2, 0) + B_y3(x[i], y[j], 0, 0, d/2) + B_y4(x[i], y[j], 0, 0, -d/2)

# %%
# Calcular el campo magnético en cada punto de la malla de z
for i in range(len(x)):
    for j in range(len(y)):
            # Sumar los campos de las 4 bobinas
           Bz[i, j] = B_z1(x[i], y[j],0, d/2, 0) + B_z2(x[i], y[j],0, -d/2, 0) + B_z3(x[i], y[j], 0, 0, d/2) +  B_z4(x[i], y[j], 0, 0, -d/2)

# %%
# Calcular el campo magnético en cada punto de la malla
for i in range(len(x)):
    for j in range(len(y)):
           B[i, j] = np.sqrt((Bx[i, j])**2 + (By[i, j])**2 + (Bz[i, j])**2)

# %%
#Visualización del campo magnético 3D
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
# Ajustes de la superficie
surf = ax.plot_surface(X, Y, B, cmap='magma', linewidth=0, antialiased=True)
# Añadir barra de color con escala y unidades
norm = plt.Normalize(B.min(), B.max())
cbar = fig.colorbar(surf, shrink=0.5, aspect=5, norm=norm, label='Magnitud del Campo (T)')
cbar.ax.tick_params(labelsize=10)
# Etiquetas, título y leyenda
ax.set_xlabel('Posición X (m)', fontsize=12)
ax.set_ylabel('Posición Y (m)', fontsize=12)
ax.set_zlabel('Magnitud del Campo (T)', fontsize=12)
plt.title('Campo Magnético Generado por 4 Bobinas Circulares en Cruz', fontsize=14)
# Habilitar la interacción 3D y ajustar vista
ax.set_zlim(B.min(), B.max())
ax.view_init(30, 45)
# Mostrar la figura
plt.show()

print("Datos bobina 1==>", N_1," Vueltas;",  R_max1, " Radio maximo (m);", I1," corriente (A)")
print("Datos bobina 2==>", N_2," Vueltas;",  R_max2, " Radio maximo (m);", I2," corriente (A)")
print("Datos bobina 3==>", N_3," Vueltas;",  R_max3, " Radio maximo (m);", I3," corriente (A)")
print("Datos bobina 4==>", N_4," Vueltas;",  R_max4, " Radio maximo (m);", I4," corriente (A)")
print("Distancia de separacion entre bobinas ==>", d, " metros")
# Out:
# Datos bobina 1==> 435  Vueltas; 0.14  Radio maximo (m); 0.025  corriente (A)
# Datos bobina 2==> 500  Vueltas; 0.14  Radio maximo (m); 0.02  corriente (A)
# Datos bobina 3==> 110  Vueltas; 0.14  Radio maximo (m); 0.05  corriente (A)
# Datos bobina 4==> 5000  Vueltas; 0.14  Radio maximo (m); 0.05  corriente (A)
# Distancia de separacion entre bobinas ==> 0.15  metros
